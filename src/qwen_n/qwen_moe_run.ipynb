# %%
import torch
from qwen3_moe_model import Qwen3ModelWithMoE
from qwen3_tok import Qwen3Tokenizer, load_tokenizer
from qwen3_moe_model import load_weight

# %%
QWEN3_CONFIG = {
    "vocab_size": 151_936,
    "context_length": 262_144,
    "emb_dim": 2048,
    "n_heads": 32,
    "n_layers": 48,
    "head_dim": 128,
    "qk_norm": True,
    "n_kv_groups": 4,
    "rope_base": 10_000_000.0,
    "dtype": torch.bfloat16,
    "num_experts": 128,
    "num_experts_per_tok": 8,
        "moe_hidden_dim": 768,
}

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
elif torch.backends.mps.is_available():
    device = torch.device("mps")
else:
    device = torch.device("cpu")

print(device)
# Out:
# mps

# %%
torch.manual_seed(123)

with device:
    model = Qwen3ModelWithMoE(QWEN3_CONFIG)

#model.to(device)
